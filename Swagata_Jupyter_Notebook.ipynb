# %% [markdown]
# # Problem Statement
# ## Prepare Detailed Report from given data and visualize it
#
# #### Data

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/given_data.png",width = 1000, height = 1)

# %% [markdown]
# ### Expected Report Layout

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/expected_result.png",width = 1000, height = 1)

# %% [markdown]
# ### Considered Approach for data transformation.
#     1: We can insert data into database and summerize it as per the requirement.
#     2: Transform data using excel.
#     3: Use python to read data from excel in rowwise fashion, transform date columns and write modified data to CSV file.
#
# For this workbook, I have considered approach no.3
#
#     I:Python Code to fetch data from excel

# %%
import xlrd
import csv
loc = "C:\\Users\\Manoj\\Desktop\\seaspan\\ManufacturingResourceTestData.xlsx"
wb = xlrd.open_workbook(loc)
sheet = wb.sheet_by_index(0)
row1 = sheet.row_values(0)

# %% [markdown]
#     II:Code for transfroming date columns from dataset and write it into CSV format.

# %%
num_rows = 2182
csvfile = open('data.csv', 'w')

for i in range(1, num_rows):
    r = sheet.row_values(i)
    count = 9
    for i in range (1, 50):
        a=r[count]
        if isinstance(r[count], str):
            a = a.replace('','0')
        data = r[6] + ',' + r[3] + ',' + str(a) + ',' + row1[count] + ','
        csvfile.write(data + '\n')
        count += 1
        if count > 55:
            break

# %% [markdown]
# After executing above code, 'data.csv' file will get generate.
# Snippet of the generated file is as follow:

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/generated_csv.png",width = 400, height = 400)

# %% [markdown]
#         III: Upload this CSV file data to Power BI.

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/upload_data.png",width = 800, height = 800)

# %% [markdown]
#         IV: Transform data in Power Query Editor

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/transform_data.png",width = 800, height = 800)

# %% [markdown]
#         V: In Power query, use group by function to summarize data according to sum(hours) per trade and date

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/summarization.png",width = 800, height = 800)

# %% [markdown]
# After applying group by function, our data will look like:

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/after_summarization.png",width = 800, height = 800)

# %% [markdown]
#         VI. Close & apply it to Power BI desktop
#         VII. Use 'Stack column chart' to visualize the report in given format.

# %%
from IPython.display import Image
Image(filename = "C:/Users/Manoj/Desktop/seaspan_docs/final_report.png",width = 800, height = 800)

# %% [markdown]
# ## Conclusion
# Above mentioned report can be design using various visualization tools and techniques.
# Final output is attached along with this workbook.
